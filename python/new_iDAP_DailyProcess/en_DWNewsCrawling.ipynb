# %%
from bs4 import BeautifulSoup
import requests
import pymysql
from datetime import datetime, timedelta,timezone
from google_trans_new import google_translator
import time
import random
import dbconfig

# %%
def gl_translator(text, lang_src, lang_tgt) :
    url_suffix_list = ['ac','ad','ae','al','am','as','at','az','ba','be','bf','bg','bi','bj','bs','bt','by','ca','cat','cc','cd','cf','cg','ch','ci','cl','cm','cn','co.ao','co.bw','co.ck','co.cr','co.id','co.il','co.in','co.jp','co.ke','co.kr','co.ls','co.ma','co.mz','co.nz','co.th','co.tz','co.ug','co.uk','co.uz','co.ve','co.vi','co.za','co.zm','co.zw','co','com.af','com.ag','com.ai','com.ar','com.au','com.bd','com.bh','com.bn','com.bo','com.br','com.bz','com.co','com.cu','com.cy','com.do','com.ec','com.eg','com.et','com.fj','com.gh','com.gi','com.gt','com.hk','com.jm','com.kh','com.kw','com.lb','com.lc','com.ly','com.mm','com.mt','com.mx','com.my','com.na','com.ng','com.ni','com.np','com.om','com.pa','com.pe','com.pg','com.ph','com.pk','com.pr','com.py','com.qa','com.sa','com.sb','com.sg','com.sl','com.sv','com.tj','com.tr','com.tw','com.ua','com.uy','com.vc','com.vn','com','cv','cx','cz','de','dj','dk','dm','dz','ee','es','eu','fi','fm','fr','ga','ge','gf','gg','gl','gm','gp','gr','gy','hn','hr','ht','hu','ie','im','io','iq','is','it','je','jo','kg','ki','kz','la','li','lk','lt','lu','lv','md','me','mg','mk','ml','mn','ms','mu','mv','mw','ne','nf','nl','no','nr','nu','pl','pn','ps','pt','ro','rs','ru','rw','sc','se','sh','si','sk','sm','sn','so','sr','st','td','tg','tk','tl','tm','tn','to','tt','us','vg','vu','ws']
    isSuccess = False
    url_suffix_inx = random.randint(0, len(url_suffix_list)-1)
    content_tw = ''
    while isSuccess == False :
        try :
            translator = google_translator(url_suffix=url_suffix_list[url_suffix_inx])        
            content_tw = translator.translate(text, lang_src=lang_src, lang_tgt=lang_tgt)
            isSuccess = True
        except Exception as e:
            url_suffix_inx = random.randint(0, len(url_suffix_list)-1)
    return content_tw   

def WebCrawling():
    host = '10.55.23.101'
    port = 33060
    user = 'root'
    passwd = "1234"
    db = 'idap'

    showPrintMSG = 1 # 0:不呈現，1:呈現 debug mode
    archiveDate = 10
    web = 'dw'
    language = 'en'
    sleep_sec = 2
    lang_src=language
    lang_tgt='zh-tw'
    
    baseUrl = "https://www.dw.com"
    targetUrl = "https://www.dw.com/en/top-stories/{}" 
    targetArr = ["s-9097", "germany/s-1432", "coronavirus/s-32798", "world/s-1429", "business/s-1431", "science/s-12526","environment/s-11798"]
    header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    }

    conn = pymysql.connect(host=host, port=port,user=user, passwd=passwd, db=db)
    cur = conn.cursor()
     
    deleteFromDate = datetime.strftime(datetime.now() - timedelta(archiveDate), '%Y%m%d')
    tag = 'industry'
    dt1 = datetime.utcnow().replace(tzinfo=timezone.utc)
    creationdate = dt1.astimezone(timezone(timedelta(hours=8))).strftime('%Y/%m/%d %H:%M:%S')
    c = 0
    for t in targetArr:
        res = requests.get(targetUrl.format(t), headers=header)
        res.encoding = 'utf-8'
        if res.status_code == 200:
            soup = BeautifulSoup(res.text, 'html.parser')
            news = soup.select('.news')
            for new in news:

                title = new.select('a > h2')[0].text
                url = baseUrl + new.select('a')[0].get('href').strip()
                
                cur.execute('select count(1) from news_daily_source where url=%s',(url))
                if cur.fetchone()[0] == 0 :
                    try:
                        
                        contentRes = requests.get(url, timeout=5)
                        contentRes.encoding = 'utf-8'
                        if contentRes.status_code == 200:
                            contentSoup = BeautifulSoup(contentRes.text, 'html.parser')
                            
                            publishdate = contentSoup.select('.smallList > li')[0].text.replace("Date", "").strip()
                            #print(publishdate,url)
                            if publishdate == 'Send us an e-mail.' :
                                continue
                            publishdate = datetime.strptime(publishdate, '%d.%m.%Y').strftime('%Y%m%d') 
                            #if publishdate < (datetime.today() - timedelta(days=1)).strftime('%Y%m%d'):
                            #    continue
                            if int(publishdate) > int(deleteFromDate) : 
                                
                                bodyContent = contentSoup.select('#bodyContent')[0]
                                contents = bodyContent.select('p')
                                content = ''.join([c.text.strip() for c in contents])
                                content_tw = gl_translator(content, lang_src, lang_tgt)
                                title_tw = gl_translator(title, lang_src, lang_tgt)
                                cur.execute('insert into news_daily_source(web, title, title_tw, content, content_tw, publishdate, url, creationdate,language,tag)values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)',(web, title, title_tw, content, content_tw, publishdate, url, creationdate,language,tag))
                                cur.execute('commit')
                                c = c + 1

                    except requests.exceptions.RequestException as e:
                        print('Exception DWNewsCrawling:'+str(e)) 
    print('DW ',creationdate,' total:',c)
    cur.close()
    conn.close()

if __name__ == "__main__":
    WebCrawling()
# Out:
# 10.02.2021 https://www.dw.com/en/bangladesh-when-will-authorities-clean-up-their-act/a-56524784
# 20.01.2021 https://www.dw.com/en/brexit-deal-the-teething-problems-and-red-tape-reality/a-56285459
# 12.11.2020 https://www.dw.com/en/tory-mp-on-covid-uk-government-has-done-everything-it-could/a-55569150
# 14.10.2020 https://www.dw.com/en/can-americans-have-faith-in-their-electoral-system/a-55274511
# 18.04.2021 https://www.dw.com/en/germany-to-offer-refuge-to-afghans-who-helped-military/a-57242960
# 15.04.2021 https://www.dw.com/en/berlin-rent-cap-overturned-by-germanys-top-court/a-57209268
# 03.04.2021 https://www.dw.com/en/us-and-germany-how-to-deal-with-the-last-holocaust-perpetrators/a-57091799
# 30.03.2021 https://www.dw.com/en/germanys-christian-churches-in-meltdown/a-57040341
# 04.04.2021 https://www.dw.com/en/wolves-and-livestock-can-they-live-in-harmony-in-germany/a-57097331
# 07.03.2021 https://www.dw.com/en/cocaine-the-drug-pipeline-to-europe/a-56782666
# 24.02.2021 https://www.dw.com/en/how-a-syrian-torture-victim-found-justice-in-germany/a-56672800
# 21.03.2021 https://www.dw.com/en/asians-in-germany-targets-of-racist-stereotypes-violence/a-56924525
# 26.03.2021 https://www.dw.com/en/traveling-germany-coronavirus/a-54124541
# 06.04.2021 https://www.dw.com/en/german-federalism-how-does-it-work/a-57042552
# 28.03.2021 https://www.dw.com/en/german-efficiency-the-roots-of-a-stereotype/a-56976234
# 19.03.2021 https://www.dw.com/en/transfer-of-stasi-records-agency-closes-a-chapter-of-east-german-history/a-56933649
# 19.02.2021 https://www.dw.com/en/celebrating-1700-years-of-jewish-life-in-germany/a-56131698
# 16.04.2021 https://www.dw.com/en/studying-in-germany-from-finance-to-fraternities/av-57228331
# 06.01.2021 https://www.dw.com/en/germany-1951-solidarity-with-nazi-mass-murderers/a-56142745
# 16.11.2020 https://www.dw.com/en/nuremberg-trials-an-important-step-for-germany-to-confront-its-nazi-past/a-55617820
# 03.10.2020 https://www.dw.com/en/germany-before-and-after-reunification/g-55082387
# 10.10.2020 https://www.dw.com/en/how-german-schools-miss-out-countrys-colonial-history/a-55230081
# 29.04.2020 https://www.dw.com/en/world-in-progress/a-5611962
# Exception DWNewsCrawling:HTTPSConnectionPool(host='www.dw.comhttp', port=443): Max retries exceeded with url: //www.dw.com/program/made-in-germany/s-3066-9798 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001FB05A8E0B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Exception DWNewsCrawling:HTTPSConnectionPool(host='www.dw.comhttp', port=443): Max retries exceeded with url: //www.dw.com/en/tv/global-3000/s-11487 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001FB05A9D0F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 15.04.2021 https://www.dw.com/en/teutonic-tesla-slayer-mercedes-unveils-eqs-electric-luxury-sedan/a-57220253
# 15.03.2021 https://www.dw.com/en/has-vw-cracked-the-code-to-overtake-tesla/a-56867182
# 08.03.2021 https://www.dw.com/en/german-court-rules-audi-not-liable-in-vw-emissions-scandal-for-now/a-56803693
# 22.03.2021 https://www.dw.com/en/why-europe-should-not-worry-about-covid-fueled-inflation/a-56927926
# 11.03.2021 https://www.dw.com/en/ecb-keeps-interest-rates-at-zero-boosts-emergency-bonds-program/av-56843362
# 11.03.2021 https://www.dw.com/en/dw-business-africa/av-56843459
# 16.02.2021 https://www.dw.com/en/dw-business/av-56586516
# 29.03.2021 https://www.dw.com/en/does-the-flu-vaccine-protect-against-covid-19/av-57043122
# Send us an e-mail. https://www.dw.com/en/tv/in-good-shape/s-11938
# 09.04.2021 https://www.dw.com/en/flying-carbon-emissions-whats-the-big-deal/a-57118935
# 06.04.2021 https://www.dw.com/en/solutions-climate-change-global-warming-permafrost-locusts-sea-level-extreme-weather-heat/a-57071503
# 19.03.2021 https://www.dw.com/en/coronavirus-fridays-for-future-fff-covid-19-pandemic-climate-strike/a-56911641
# 08.04.2021 https://www.dw.com/en/agriculture-seeds-seed-laws-agribusinesses-climate-change-food-security-seed-sovereignty-bayer/a-57118595
# 01.04.2021 https://www.dw.com/en/in-greece-women-activists-sing-and-dance-against-oil-and-gas/a-57030618
# 31.03.2021 https://www.dw.com/en/global-rainforest-destruction-saw-a-surge-in-2020-study-finds/a-57057241
# 08.04.2021 https://www.dw.com/en/troop-of-monkeys-escape-german-wildlife-park/a-57137044
# 18.02.2021 https://www.dw.com/en/making-peace-with-nature/a-56615328
# 05.02.2021 https://www.dw.com/en/learning-to-live-with-el-lobo-mexican-wolves-make-a-comeback/a-56360555
# 13.04.2021 https://www.dw.com/en/how-chinas-mines-rule-the-market-of-critical-raw-materials/a-57148375
# 13.04.2021 https://www.dw.com/en/rare-rocks-reuse-and-substitutes-of-critical-resources/a-57148472
# 13.04.2021 https://www.dw.com/en/toxic-and-radioactive-the-damage-from-mining-rare-elements/a-57148185
# 09.04.2021 https://www.dw.com/en/carbon-neutral-flying-aviation-co2-traveling/a-57001567
# 09.04.2021 https://www.dw.com/en/the-battle-over-greenlands-untapped-natural-resources/a-57138809
# 07.04.2021 https://www.dw.com/en/czech-researchers-develop-revolutionary-nuclear-heating-plant/a-57072924
# DW  2021/04/28 10:25:08  total: 0

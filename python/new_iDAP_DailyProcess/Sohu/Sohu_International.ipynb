# %%
#############################################
# 網站名稱：搜狐
# 網址： https://www.sohu.com/c/8/1461
# 爬取類型： 國際
# 爬取範圍： 今日、昨日
#############################################

from bs4 import BeautifulSoup
import requests
from datetime import datetime, timedelta
import pymysql
import json


def WebCrawling(days=3):
    host = '10.55.23.101'
    port = 33060
    user = 'root'
    passwd = "1234"
    db = 'idap'
    web = "Sohu_International" 
    tag = "International"

    targetUrl = "https://v2.sohu.com/public-api/feed?scene=CATEGORY&sceneId=1461&page={}&size=20"
    baseUrl = "https://www.sohu.com/a/{}_{}"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'
    }

    conn = pymysql.connect(host=host, port=port,
                           user=user, passwd=passwd, db=db)
    cur = conn.cursor()
    page = 1

    while(True):
        res = requests.get(targetUrl.format(page), headers=headers)
        res.encoding = 'utf-8'
        if res.status_code == 403:
            return
        if res.status_code == 200:
            news = json.loads(res.text)
            for new in news:
                url = baseUrl.format(new["id"], new["authorId"])
                title = new["title"]

                creationdate = datetime.now()
                content = ''

                contentRes = requests.get(url, headers=headers)
                contentRes.encoding = 'utf-8'
                if contentRes.status_code == 200:
                    contentSoup = BeautifulSoup(contentRes.text, 'lxml')
                    publishdate = contentSoup.select('#news-time')[0].text[0:10].replace('-', '')
                    if publishdate < (datetime.today() - timedelta(days=days)).strftime('%Y%m%d'):
                        return

                    contents = contentSoup.select('article.article > p:not(.ql-align-center):not([data-role="editor-name"])') + contentSoup.select('div.hidden-content > p:not(.ql-align-center)')
                    content = ' '.join([c.text.strip() for c in contents])
                    content = content.replace("返回搜狐，查看更多", "")         
                    contentRes.close()

                    cur.execute('select count(1) from news_daily where url=%s',(url))
                    if cur.fetchone()[0] == 0 :
                        cur.execute('insert ignore into news_daily(web, title, content, tag, publishdate, url, creationdate)values(%s, %s, %s, %s, %s, %s, %s)', (web, title, content, tag, publishdate, url, creationdate))
                        cur.execute('commit')
                        c=c+1

        res.close()
        page = page + 1

    cur.close()
    conn.close()


if __name__ == "__main__":
    host = 'pc89600059495s'
    port = 33060
    user = 'root'
    passwd = "1234"
    db = 'idap'

    web = "搜狐"

    WebCrawling()

# %%
days=3
from bs4 import BeautifulSoup
import requests
from datetime import datetime, timedelta
import pymysql
import json
host = '10.55.23.101'
port = 33060
user = 'root'
passwd = "1234"
db = 'idap'
web = "Sohu_International" 
tag = "International"

targetUrl = "https://v2.sohu.com/public-api/feed?scene=CATEGORY&sceneId=1461&page={}&size=20"
baseUrl = "https://www.sohu.com/a/{}_{}"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'
}

conn = pymysql.connect(host=host, port=port,
                       user=user, passwd=passwd, db=db)
cur = conn.cursor()
page = 1
c=0
while(page<20):
    res = requests.get(targetUrl.format(page), headers=headers)
    res.encoding = 'utf-8'
    if res.status_code == 403:
        break
    if res.status_code == 200:
        news = json.loads(res.text)
        for new in news:
            url = baseUrl.format(new["id"], new["authorId"])
            title = new["title"]

            creationdate = datetime.now()
            content = ''

            contentRes = requests.get(url, headers=headers)
            contentRes.encoding = 'utf-8'
            if contentRes.status_code == 200:
                contentSoup = BeautifulSoup(contentRes.text, 'lxml')
                publishdate = contentSoup.select('#news-time')[0].text[0:10].replace('-', '')
                if publishdate < (datetime.today() - timedelta(days=days)).strftime('%Y%m%d'):
                    break

                contents = contentSoup.select('article.article > p:not(.ql-align-center):not([data-role="editor-name"])') + contentSoup.select('div.hidden-content > p:not(.ql-align-center)')
                content = ' '.join([c.text.strip() for c in contents])
                content = content.replace("返回搜狐，查看更多", "")         
                contentRes.close()
                print(url)
                cur.execute('select count(1) from news_daily where url=%s',(url))
                if cur.fetchone()[0] == 0 :
                    cur.execute('insert ignore into news_daily(web, title, content, tag, publishdate, url, creationdate)values(%s, %s, %s, %s, %s, %s, %s)', (web, title, content, tag, publishdate, url, creationdate))
                    cur.execute('commit')
                    c=c+1

    res.close()
    page = page + 1

cur.close()
conn.close()
# Out:
# https://www.sohu.com/a/447940695_162758
# https://www.sohu.com/a/447940378_115239
# https://www.sohu.com/a/447944337_260616
# https://www.sohu.com/a/447944517_162522
# https://www.sohu.com/a/447940582_267106
# https://www.sohu.com/a/447935152_123753
# https://www.sohu.com/a/447943547_313745
# https://www.sohu.com/a/447943732_255783
# https://www.sohu.com/a/447943890_123753
# https://www.sohu.com/a/447938146_267106
# https://www.sohu.com/a/447945766_115479
# https://www.sohu.com/a/447940790_162758
# https://www.sohu.com/a/447942160_162522
# https://www.sohu.com/a/447942226_162522
# https://www.sohu.com/a/447943125_162758
# https://www.sohu.com/a/447944576_162758
# https://www.sohu.com/a/447942325_162522
# https://www.sohu.com/a/447945631_162758
# https://www.sohu.com/a/447940379_116897
# https://www.sohu.com/a/447926840_267106
# https://www.sohu.com/a/447939225_162522
# https://www.sohu.com/a/447941053_162758
# https://www.sohu.com/a/447923075_267106
# https://www.sohu.com/a/447945546_162758
# https://www.sohu.com/a/447943922_162522
# https://www.sohu.com/a/447938687_162522
# https://www.sohu.com/a/447934293_119038
# https://www.sohu.com/a/447905067_115479
# https://www.sohu.com/a/447901152_161795
# https://www.sohu.com/a/447934399_119038
# https://www.sohu.com/a/447930762_162522
# https://www.sohu.com/a/447888687_600465
# https://www.sohu.com/a/447899490_260616
# https://www.sohu.com/a/447909923_267106
# https://www.sohu.com/a/447934393_119038
# https://www.sohu.com/a/447942094_162522
# https://www.sohu.com/a/447893971_260616
# https://www.sohu.com/a/447912431_267106
# https://www.sohu.com/a/447934701_119038
# https://www.sohu.com/a/447888578_600465
# https://www.sohu.com/a/447930658_162522
# https://www.sohu.com/a/447908695_267106
# https://www.sohu.com/a/447935363_119038
# https://www.sohu.com/a/447930863_162522
# https://www.sohu.com/a/447907360_267106
# https://www.sohu.com/a/447853433_362042
# https://www.sohu.com/a/447931120_162522
# https://www.sohu.com/a/447873873_115239
# https://www.sohu.com/a/447853610_114988
# https://www.sohu.com/a/447861215_255783
# https://www.sohu.com/a/447903219_267106
# https://www.sohu.com/a/447875355_260616
# https://www.sohu.com/a/447895346_162758
# https://www.sohu.com/a/447843068_115362
# https://www.sohu.com/a/447939567_162522
# https://www.sohu.com/a/447854769_115402
# https://www.sohu.com/a/447868929_115479
# https://www.sohu.com/a/447865216_123753
# https://www.sohu.com/a/447859371_161623
# https://www.sohu.com/a/447899811_162758
# https://www.sohu.com/a/447902275_267106
# https://www.sohu.com/a/447861308_123753
